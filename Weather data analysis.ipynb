# %% [markdown]
# Different functions that you would require to define for this project has been mentioned in the code block. All the parameters and the task, a function would do, have been mentioned there.
#
#     Load the weather_2012 data csv file and store it in weather variable. The path of the dataset has been stored in the variable path for you.
#     Check the categorical and numerical variables. You can check it by calling categorical and numerical functions.
#     Check the distribution of a specific value like the number of times the weather was exactly Cloudy in the given column. Feel free to check on other values. You can check it by calling the function clear with respective parameters.
#     By using the index of the value or name of the value you can check the number of counts. Now suppose you want to check some instances based on a specific condition like when the wind speed was above 35 and visibility was 25. You can directly check it by calling the function instances_based_condition with respective parameters and store the resulting dataframe in wind_speed_35_vis_25.
#     You have temperature data and want to calculate the mean temperature recorded by month. You can generate a pivot table that contains the aggregated values(like mean, max, min, sum, len) recorded by month. You can call the function agg_values_ina_month with respective parameters.
#     To groupby based on a column like you want to groupby on Weather column and then aggregate the mean values of each column for different types of weather using mean. You can call the function group_values and store the resulting dataframe in mean_weather. Feel free to try on different aggregated functions like max, min, sum, len
#     You want to convert Celsius temperature into Fahrenheit temperatures. Call the function convert to do the same.

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('weather.csv')

# %%
df.head()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog

# %% [markdown]
# Check the categorical and numerical variables. You can check it by calling categorical and numerical functions.

# %%
df.info()#gives the type of object null count etc
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date/Time           8784 non-null   object
#  1   Temp (C)            8784 non-null   float64
#  2   Dew Point Temp (C)  8784 non-null   float64
#  3   Rel Hum (%)         8784 non-null   int64
#  4   Wind Spd (km/h)     8784 non-null   int64
#  5   Visibility (km)     8784 non-null   float64
#  6   Stn Press (kPa)     8784 non-null   float64
#  7   Weather             8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
df.isnull().sum() #Gives the total number of null columns
# Out:
# Date/Time             0
# Temp (C)              0
# Dew Point Temp (C)    0
# Rel Hum (%)           0
# Wind Spd (km/h)       0
# Visibility (km)       0
# Stn Press (kPa)       0
# Weather               0
# dtype: int64

# %% [markdown]
# --------------------------------------------------------------------------------------

# %%
a1='a'

# %%
a1.upper()
# Out:
# 'A'

# %% [markdown]
# --------------------------------------------------------

# %%
cloudy_weather=df[df['Weather'] == 'Cloudy']
print(cloudy_weather)
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 17    2012-01-01 17:00:00       3.0                 0.0           81
# 20    2012-01-01 20:00:00       3.2                 1.3           87
# 21    2012-01-01 21:00:00       4.0                 1.7           85
# 23    2012-01-01 23:00:00       5.3                 2.0           79
# 25    2012-01-02 01:00:00       4.6                 0.0           72
# ...                   ...       ...                 ...          ...
# 8761  2012-12-31 01:00:00     -10.7               -14.0           77
# 8762  2012-12-31 02:00:00     -10.1               -13.4           77
# 8764  2012-12-31 04:00:00     -10.5               -12.8           83
# 8765  2012-12-31 05:00:00     -10.2               -12.4           84
# 8766  2012-12-31 06:00:00      -9.7               -11.7           85
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa) Weather
# 17                 13             16.1            99.81  Cloudy
# 20                 19             25.0            99.50  Cloudy
# 21                 20             25.0            99.39  Cloudy
# 23                 30             25.0            99.31  Cloudy
# 25                 39             25.0            99.26  Cloudy
# ...               ...              ...              ...     ...
# 8761               15             25.0           101.50  Cloudy
# 8762                9             25.0           101.45  Cloudy
# 8764               11             25.0           101.34  Cloudy
# 8765                6             25.0           101.28  Cloudy
# 8766                4             25.0           101.23  Cloudy
#
# [1728 rows x 8 columns]

# %%
Weather=cloudy_weather['Weather']
print(Weather)
# Out:
# 17      Cloudy
# 20      Cloudy
# 21      Cloudy
# 23      Cloudy
# 25      Cloudy
#          ...
# 8761    Cloudy
# 8762    Cloudy
# 8764    Cloudy
# 8765    Cloudy
# 8766    Cloudy
# Name: Weather, Length: 1728, dtype: object

# %%
times_cloudy_weather = Weather.count()
print(times_cloudy_weather)
# Out:
# 1728

# %% [markdown]
# By using the index of the value or name of the value you can check the number of counts. Now suppose you want to check some instances based on a specific condition like when the wind speed was above 35 and visibility was 25. You can directly check it by calling the function instances_based_condition with respective parameters and store the resulting dataframe in wind_speed_35_vis_25.

# %%
df[(df['Wind Spd (km/h)'] > 35) & (df['Visibility (km)'] == 25)]
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 25    2012-01-02 01:00:00       4.6                 0.0           72
# 409   2012-01-18 01:00:00       3.7                -2.1           66
# 410   2012-01-18 02:00:00       0.5                -4.0           72
# 411   2012-01-18 03:00:00      -3.5                -8.2           70
# 412   2012-01-18 04:00:00      -6.1               -10.9           69
# 557   2012-01-24 05:00:00       3.7                -0.2           76
# 583   2012-01-25 07:00:00      -3.9               -10.0           63
# 670   2012-01-28 22:00:00       2.3                -2.0           73
# 672   2012-01-29 00:00:00       1.5                -5.0           62
# 673   2012-01-29 01:00:00       0.9                -5.3           63
# 674   2012-01-29 02:00:00       0.3                -5.8           64
# 675   2012-01-29 03:00:00      -0.2                -6.0           65
# 676   2012-01-29 04:00:00      -0.9                -7.0           63
# 677   2012-01-29 05:00:00      -1.5                -7.8           62
# 678   2012-01-29 06:00:00      -2.0                -8.1           63
# 1494  2012-03-03 06:00:00       1.5                -1.6           80
# 1506  2012-03-03 18:00:00       3.7                -4.3           56
# 1507  2012-03-03 19:00:00       3.4                -4.0           58
# 1508  2012-03-03 20:00:00       3.2                -3.9           60
# 1509  2012-03-03 21:00:00       2.9                -3.6           62
# 1510  2012-03-03 22:00:00       2.8                -3.4           64
# 1628  2012-03-08 20:00:00       5.0                 1.6           79
# 2571  2012-04-17 03:00:00      15.4                 6.3           55
# 2572  2012-04-17 04:00:00      14.5                 6.1           57
# 2714  2012-04-23 02:00:00       1.1                -1.1           85
# 2715  2012-04-23 03:00:00       1.7                -0.7           84
# 2716  2012-04-23 04:00:00       2.0                -0.7           82
# 2732  2012-04-23 20:00:00       5.7                 3.6           86
# 2733  2012-04-23 21:00:00       5.6                 3.5           86
# 5827  2012-08-30 19:00:00      25.5                16.3           57
# 5828  2012-08-30 20:00:00      24.5                15.2           56
# 5829  2012-08-30 21:00:00      24.5                15.6           58
# 5830  2012-08-30 22:00:00      24.2                15.5           58
# 5831  2012-08-30 23:00:00      23.7                15.6           60
# 6043  2012-09-08 19:00:00      19.9                14.6           72
# 6044  2012-09-08 20:00:00      19.2                13.2           68
# 6045  2012-09-08 21:00:00      16.1                12.7           80
# 6288  2012-09-19 00:00:00      12.8                11.2           90
# 6835  2012-10-11 19:00:00       8.4                 2.2           65
# 7266  2012-10-29 18:00:00      14.2                 9.2           72
# 7267  2012-10-29 19:00:00      14.0                 9.6           75
# 7268  2012-10-29 20:00:00      14.3                 9.7           74
# 7269  2012-10-29 21:00:00      14.0                 9.7           75
# 7270  2012-10-29 22:00:00      14.2                 9.8           75
# 7271  2012-10-29 23:00:00      14.1                10.0           76
# 7272  2012-10-30 00:00:00      14.6                10.2           75
# 7273  2012-10-30 01:00:00      14.6                10.4           76
# 7274  2012-10-30 02:00:00      14.1                10.3           78
# 7275  2012-10-30 03:00:00      13.9                10.6           80
# 7277  2012-10-30 05:00:00      13.7                10.5           81
# 7278  2012-10-30 06:00:00      13.6                10.5           82
# 7608  2012-11-13 00:00:00      14.8                10.0           73
# 7611  2012-11-13 03:00:00       7.9                 5.6           85
# 7868  2012-11-23 20:00:00      10.0                 5.4           73
# 7869  2012-11-23 21:00:00       9.3                 4.1           70
# 7876  2012-11-24 04:00:00       4.1                -2.2           63
# 8538  2012-12-21 18:00:00       1.4                 0.3           92
# 8659  2012-12-26 19:00:00      -9.6               -13.1           76
# 8662  2012-12-26 22:00:00      -9.7               -12.8           78
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)        Weather
# 25                 39             25.0            99.26         Cloudy
# 409                83             25.0            98.36  Mostly Cloudy
# 410                70             25.0            98.62  Mostly Cloudy
# 411                57             25.0            99.00  Mostly Cloudy
# 412                48             25.0            99.36           Snow
# 557                41             25.0           100.37         Cloudy
# 583                37             25.0           101.79  Mostly Cloudy
# 670                37             25.0            99.85  Mostly Cloudy
# 672                57             25.0            99.96   Mainly Clear
# 673                52             25.0           100.09   Mainly Clear
# 674                52             25.0           100.21   Mainly Clear
# 675                43             25.0           100.34   Mainly Clear
# 676                43             25.0           100.47   Mainly Clear
# 677                43             25.0           100.59   Mainly Clear
# 678                44             25.0           100.68   Mainly Clear
# 1494               43             25.0            99.02   Mainly Clear
# 1506               48             25.0            98.82  Mostly Cloudy
# 1507               44             25.0            98.92   Mainly Clear
# 1508               50             25.0            98.96   Mainly Clear
# 1509               46             25.0            98.98           Snow
# 1510               57             25.0            99.07           Snow
# 1628               41             25.0            99.90           Rain
# 2571               37             25.0           100.61   Mainly Clear
# 2572               37             25.0           100.80   Mainly Clear
# 2714               44             25.0           100.32      Rain,Snow
# 2715               52             25.0           100.11      Rain,Snow
# 2716               44             25.0            99.82           Rain
# 2732               41             25.0            98.54         Cloudy
# 2733               37             25.0            98.51           Rain
# 5827               43             25.0           100.49  Mostly Cloudy
# 5828               39             25.0           100.51  Mostly Cloudy
# 5829               44             25.0           100.53   Mainly Clear
# 5830               41             25.0           100.54   Mainly Clear
# 5831               37             25.0           100.57   Mainly Clear
# 6043               37             25.0            99.44  Mostly Cloudy
# 6044               43             25.0            99.51   Mainly Clear
# 6045               44             25.0            99.67  Mostly Cloudy
# 6288               37             25.0            99.78         Cloudy
# 6835               37             25.0           101.13           Rain
# 7266               44             25.0            99.83  Mostly Cloudy
# 7267               50             25.0            99.65  Mostly Cloudy
# 7268               52             25.0            99.55         Cloudy
# 7269               48             25.0            99.46  Mostly Cloudy
# 7270               50             25.0            99.37         Cloudy
# 7271               54             25.0            99.33         Cloudy
# 7272               41             25.0            99.28         Cloudy
# 7273               52             25.0            99.23  Mostly Cloudy
# 7274               37             25.0            99.31  Mostly Cloudy
# 7275               41             25.0            99.21   Rain Showers
# 7277               37             25.0            99.32   Mainly Clear
# 7278               37             25.0            99.31   Rain Showers
# 7608               48             25.0           100.94           Rain
# 7611               41             25.0           101.45           Rain
# 7868               39             25.0            99.71         Cloudy
# 7869               39             25.0            99.72         Cloudy
# 7876               37             25.0            99.56  Mostly Cloudy
# 8538               46             25.0            97.56           Rain
# 8659               39             25.0           102.03         Cloudy
# 8662               37             25.0           101.70         Cloudy

# %% [markdown]
# You have temperature data and want to calculate the mean temperature recorded by month. You can generate a pivot table that contains the aggregated values(like mean, max, min, sum, len) recorded by month. You can call the function agg_values_ina_month with respective parameters.

# %% [markdown]
# # Slicing of month from date /time panda series

# %%
d1=df['Date/Time']
d2=pd.to_datetime(df['Date/Time'])
d2=d2.dt.month
d2
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 8779    12
# 8780    12
# 8781    12
# 8782    12
# 8783    12
# Name: Date/Time, Length: 8784, dtype: int64

# %%
agg_values_ina_month = df.pivot_table(index=d2,values=['Dew Point Temp (C)'],aggfunc={'Dew Point Temp (C)':np.mean})
print(agg_values_ina_month.head(10))
# Out:
#            Dew Point Temp (C)
# Date/Time
# 1                  -12.294758
# 2                   -9.221695
# 3                   -3.488575
# 4                   -1.934583
# 5                    8.080780
# 6                   11.738056
# 7                   14.595430
# 8                   15.644758
# 9                   10.757917
# 10                   6.533468

# %% [markdown]
# To groupby based on a column like you want to groupby on Weather column and then aggregate the mean values of each column for different types of weather using mean. You can call the function group_values and store the resulting dataframe in mean_weather. Feel free to try on different aggregated functions like max, min, sum, len

# %%
mean_weather = df.groupby(['Weather']).agg([np.mean,np.max,np.min,np.sum,'count',len])
mean_weather
# Out:
#                                           Temp (C)                             \
#                                               mean  amax  amin      sum count
# Weather
# Clear                                     6.825716  32.8 -23.3   9050.9  1326
# Cloudy                                    7.970544  30.5 -21.4  13773.1  1728
# Drizzle                                   7.353659  18.8   1.1    301.5    41
# Drizzle,Fog                               8.067500  19.9   0.0    645.4    80
# Drizzle,Ice Pellets,Fog                   0.400000   0.4   0.4      0.4     1
# Drizzle,Snow                              1.050000   1.2   0.9      2.1     2
# Drizzle,Snow,Fog                          0.693333   1.1   0.3     10.4    15
# Fog                                       4.303333  20.8 -16.0    645.5   150
# Freezing Drizzle                         -5.657143  -2.3  -9.0    -39.6     7
# Freezing Drizzle,Fog                     -2.533333  -0.3  -6.4    -15.2     6
# Freezing Drizzle,Haze                    -5.433333  -5.0  -5.8    -16.3     3
# Freezing Drizzle,Snow                    -5.109091  -3.3  -8.3    -56.2    11
# Freezing Fog                             -7.575000  -0.1 -19.0    -30.3     4
# Freezing Rain                            -3.885714   0.3  -6.5    -54.4    14
# Freezing Rain,Fog                        -2.225000   0.1  -6.1     -8.9     4
# Freezing Rain,Haze                       -4.900000  -4.9  -4.9     -9.8     2
# Freezing Rain,Ice Pellets,Fog            -2.600000  -2.6  -2.6     -2.6     1
# Freezing Rain,Snow Grains                -5.000000  -5.0  -5.0     -5.0     1
# Haze                                     -0.200000  14.1 -11.5     -3.2    16
# Mainly Clear                             12.558927  33.0 -22.8  26449.1  2106
# Moderate Rain,Fog                         1.700000   1.7   1.7      1.7     1
# Moderate Snow                            -5.525000  -4.9  -6.3    -22.1     4
# Moderate Snow,Blowing Snow               -5.450000  -5.4  -5.5    -10.9     2
# Mostly Cloudy                            10.574287  32.4 -23.2  21878.2  2069
# Rain                                      9.786275  22.8   0.3   2994.6   306
# Rain Showers                             13.722340  26.4   1.6   2579.8   188
# Rain Showers,Fog                         12.800000  12.8  12.8     12.8     1
# Rain Showers,Snow Showers                 2.150000   2.2   2.1      4.3     2
# Rain,Fog                                  8.273276  21.7   0.0    959.7   116
# Rain,Haze                                 4.633333   5.5   4.0     13.9     3
# Rain,Ice Pellets                          0.600000   0.6   0.6      0.6     1
# Rain,Snow                                 1.055556   1.7   0.6     19.0    18
# Rain,Snow Grains                          1.900000   1.9   1.9      1.9     1
# Rain,Snow,Fog                             0.800000   0.8   0.8      0.8     1
# Rain,Snow,Ice Pellets                     1.100000   1.3   0.9      4.4     4
# Snow                                     -4.524103   3.7 -16.7  -1764.4   390
# Snow Pellets                              0.700000   0.7   0.7      0.7     1
# Snow Showers                             -3.506667   2.9 -13.3   -210.4    60
# Snow Showers,Fog                        -10.675000 -10.0 -11.3    -42.7     4
# Snow,Blowing Snow                        -5.410526  -1.4 -12.0   -102.8    19
# Snow,Fog                                 -5.075676   1.1 -10.1   -187.8    37
# Snow,Haze                                -4.020000  -3.6  -4.3    -20.1     5
# Snow,Ice Pellets                         -1.883333   0.8  -4.3    -11.3     6
# Thunderstorms                            24.150000  26.7  21.6     48.3     2
# Thunderstorms,Heavy Rain Showers         10.900000  10.9  10.9     10.9     1
# Thunderstorms,Moderate Rain Showers,Fog  19.600000  19.6  19.6     19.6     1
# Thunderstorms,Rain                       20.433333  21.3  19.4     61.3     3
# Thunderstorms,Rain Showers               20.037500  25.5  11.0    320.6    16
# Thunderstorms,Rain Showers,Fog           21.600000  22.9  19.5     64.8     3
# Thunderstorms,Rain,Fog                   20.600000  20.6  20.6     20.6     1
#
#                                                 Dew Point Temp (C)        \
#                                             len               mean  amax
# Weather
# Clear                                    1326.0           0.089367  20.4
# Cloudy                                   1728.0           2.375810  22.6
# Drizzle                                    41.0           5.504878  17.7
# Drizzle,Fog                                80.0           7.033750  19.1
# Drizzle,Ice Pellets,Fog                     1.0          -0.700000  -0.7
# Drizzle,Snow                                2.0           0.150000   0.2
# Drizzle,Snow,Fog                           15.0           0.120000   0.6
# Fog                                       150.0           3.159333  19.6
# Freezing Drizzle                            7.0          -8.000000  -3.3
# Freezing Drizzle,Fog                        6.0          -4.183333  -2.3
# Freezing Drizzle,Haze                       3.0          -8.000000  -7.7
# Freezing Drizzle,Snow                      11.0          -7.072727  -4.6
# Freezing Fog                                4.0          -9.250000  -0.3
# Freezing Rain                              14.0          -6.078571  -1.7
# Freezing Rain,Fog                           4.0          -3.750000  -0.9
# Freezing Rain,Haze                          2.0          -7.450000  -7.4
# Freezing Rain,Ice Pellets,Fog               1.0          -3.700000  -3.7
# Freezing Rain,Snow Grains                   1.0          -7.300000  -7.3
# Haze                                       16.0          -2.975000  11.1
# Mainly Clear                             2106.0           4.581671  21.2
# Moderate Rain,Fog                           1.0           0.800000   0.8
# Moderate Snow                               4.0          -7.250000  -6.7
# Moderate Snow,Blowing Snow                  2.0          -6.500000  -6.4
# Mostly Cloudy                            2069.0           3.131174  24.4
# Rain                                      306.0           7.042810  20.4
# Rain Showers                              188.0           9.187766  23.0
# Rain Showers,Fog                            1.0          12.100000  12.1
# Rain Showers,Snow Showers                   2.0          -1.500000  -1.2
# Rain,Fog                                  116.0           7.219828  19.5
# Rain,Haze                                   3.0           2.066667   2.9
# Rain,Ice Pellets                            1.0          -0.600000  -0.6
# Rain,Snow                                  18.0          -0.566667   0.5
# Rain,Snow Grains                            1.0          -2.100000  -2.1
# Rain,Snow,Fog                               1.0           0.300000   0.3
# Rain,Snow,Ice Pellets                       4.0          -0.175000   0.1
# Snow                                      390.0          -7.623333   0.3
# Snow Pellets                                1.0          -6.400000  -6.4
# Snow Showers                               60.0          -7.866667  -0.7
# Snow Showers,Fog                            4.0         -11.900000 -11.1
# Snow,Blowing Snow                          19.0          -7.621053  -2.9
# Snow,Fog                                   37.0          -6.364865   0.8
# Snow,Haze                                   5.0          -6.860000  -6.4
# Snow,Ice Pellets                            6.0          -3.666667  -1.7
# Thunderstorms                               2.0          19.750000  20.1
# Thunderstorms,Heavy Rain Showers            1.0           9.000000   9.0
# Thunderstorms,Moderate Rain Showers,Fog     1.0          18.500000  18.5
# Thunderstorms,Rain                          3.0          18.533333  19.1
# Thunderstorms,Rain Showers                 16.0          17.618750  23.1
# Thunderstorms,Rain Showers,Fog              3.0          18.700000  21.3
# Thunderstorms,Rain,Fog                      1.0          18.600000  18.6
#
#                                                        ... Visibility (km)  \
#                                          amin     sum  ...            amin
# Weather                                                ...
# Clear                                   -28.5   118.5  ...            11.3
# Cloudy                                  -26.8  4105.4  ...            11.3
# Drizzle                                  -0.2   225.7  ...             6.4
# Drizzle,Fog                              -1.6   562.7  ...             1.0
# Drizzle,Ice Pellets,Fog                  -0.7    -0.7  ...             4.0
# Drizzle,Snow                              0.1     0.3  ...             9.7
# Drizzle,Snow,Fog                         -0.1     1.8  ...             2.4
# Fog                                     -17.2   473.9  ...             0.2
# Freezing Drizzle                        -12.2   -56.0  ...             4.8
# Freezing Drizzle,Fog                     -9.0   -25.1  ...             3.6
# Freezing Drizzle,Haze                    -8.3   -24.0  ...             2.0
# Freezing Drizzle,Snow                   -10.4   -77.8  ...             2.4
# Freezing Fog                            -22.9   -37.0  ...             0.2
# Freezing Rain                            -9.0   -85.1  ...             2.8
# Freezing Rain,Fog                        -8.7   -15.0  ...             2.8
# Freezing Rain,Haze                       -7.5   -14.9  ...             2.0
# Freezing Rain,Ice Pellets,Fog            -3.7    -3.7  ...             8.0
# Freezing Rain,Snow Grains                -7.3    -7.3  ...             4.8
# Haze                                    -16.0   -47.6  ...             4.8
# Mainly Clear                            -28.0  9649.0  ...            12.9
# Moderate Rain,Fog                         0.8     0.8  ...             6.4
# Moderate Snow                            -7.6   -29.0  ...             0.6
# Moderate Snow,Blowing Snow               -6.6   -13.0  ...             0.6
# Mostly Cloudy                           -28.5  6478.4  ...            11.3
# Rain                                     -5.7  2155.1  ...             4.0
# Rain Showers                             -7.2  1727.3  ...             6.4
# Rain Showers,Fog                         12.1    12.1  ...             6.4
# Rain Showers,Snow Showers                -1.8    -3.0  ...            19.3
# Rain,Fog                                 -1.2   837.5  ...             2.0
# Rain,Haze                                 1.0     6.2  ...             4.0
# Rain,Ice Pellets                         -0.6    -0.6  ...             9.7
# Rain,Snow                                -1.7   -10.2  ...             2.4
# Rain,Snow Grains                         -2.1    -2.1  ...            25.0
# Rain,Snow,Fog                             0.3     0.3  ...             6.4
# Rain,Snow,Ice Pellets                    -0.7    -0.7  ...             4.8
# Snow                                    -24.6 -2973.1  ...             1.0
# Snow Pellets                             -6.4    -6.4  ...             2.4
# Snow Showers                            -19.3  -472.0  ...             2.4
# Snow Showers,Fog                        -12.7   -47.6  ...             4.0
# Snow,Blowing Snow                       -16.2  -144.8  ...             0.6
# Snow,Fog                                -12.0  -235.5  ...             1.2
# Snow,Haze                                -7.2   -34.3  ...             4.0
# Snow,Ice Pellets                         -5.9   -22.0  ...             2.8
# Thunderstorms                            19.4    39.5  ...            24.1
# Thunderstorms,Heavy Rain Showers          9.0     9.0  ...             2.4
# Thunderstorms,Moderate Rain Showers,Fog  18.5    18.5  ...             3.2
# Thunderstorms,Rain                       18.2    55.6  ...            16.1
# Thunderstorms,Rain Showers                7.0   281.9  ...             6.4
# Thunderstorms,Rain Showers,Fog           16.1    56.1  ...             9.7
# Thunderstorms,Rain,Fog                   18.6    18.6  ...             4.8
#
#                                                                 \
#                                              sum count     len
# Weather
# Clear                                    39983.2  1326  1326.0
# Cloudy                                   46009.3  1728  1728.0
# Drizzle                                    735.2    41    41.0
# Drizzle,Fog                                420.6    80    80.0
# Drizzle,Ice Pellets,Fog                      4.0     1     1.0
# Drizzle,Snow                                21.0     2     2.0
# Drizzle,Snow,Fog                            82.7    15    15.0
# Fog                                        937.2   150   150.0
# Freezing Drizzle                            64.4     7     7.0
# Freezing Drizzle,Fog                        31.6     6     6.0
# Freezing Drizzle,Haze                        8.0     3     3.0
# Freezing Drizzle,Snow                       64.6    11    11.0
# Freezing Fog                                 2.6     4     4.0
# Freezing Rain                              115.4    14    14.0
# Freezing Rain,Fog                           30.2     4     4.0
# Freezing Rain,Haze                           4.8     2     2.0
# Freezing Rain,Ice Pellets,Fog                8.0     1     1.0
# Freezing Rain,Snow Grains                    4.8     1     1.0
# Haze                                       125.3    16    16.0
# Mainly Clear                             72161.8  2106  2106.0
# Moderate Rain,Fog                            6.4     1     1.0
# Moderate Snow                                3.0     4     4.0
# Moderate Snow,Blowing Snow                   1.2     2     2.0
# Mostly Cloudy                            64664.2  2069  2069.0
# Rain                                      5770.1   306   306.0
# Rain Showers                              4289.5   188   188.0
# Rain Showers,Fog                             6.4     1     1.0
# Rain Showers,Snow Showers                   43.4     2     2.0
# Rain,Fog                                   797.3   116   116.0
# Rain,Haze                                   20.1     3     3.0
# Rain,Ice Pellets                             9.7     1     1.0
# Rain,Snow                                  210.1    18    18.0
# Rain,Snow Grains                            25.0     1     1.0
# Rain,Snow,Fog                                6.4     1     1.0
# Rain,Snow,Ice Pellets                       24.0     4     4.0
# Snow                                      4357.0   390   390.0
# Snow Pellets                                 2.4     1     1.0
# Snow Showers                              1209.5    60    60.0
# Snow Showers,Fog                            28.1     4     4.0
# Snow,Blowing Snow                           78.0    19    19.0
# Snow,Fog                                   167.9    37    37.0
# Snow,Haze                                   23.2     5     5.0
# Snow,Ice Pellets                            44.5     6     6.0
# Thunderstorms                               49.1     2     2.0
# Thunderstorms,Heavy Rain Showers             2.4     1     1.0
# Thunderstorms,Moderate Rain Showers,Fog      3.2     1     1.0
# Thunderstorms,Rain                          59.5     3     3.0
# Thunderstorms,Rain Showers                 254.3    16    16.0
# Thunderstorms,Rain Showers,Fog              29.1     3     3.0
# Thunderstorms,Rain,Fog                       4.8     1     1.0
#
#                                         Stn Press (kPa)                  \
#                                                    mean    amax    amin
# Weather
# Clear                                        101.587443  103.63   99.52
# Cloudy                                       100.911441  103.65   98.39
# Drizzle                                      100.435366  101.56   97.84
# Drizzle,Fog                                  100.786625  102.07   98.65
# Drizzle,Ice Pellets,Fog                      100.790000  100.79  100.79
# Drizzle,Snow                                 100.890000  101.15  100.63
# Drizzle,Snow,Fog                              99.281333  100.15   97.79
# Fog                                          101.184067  103.04   98.31
# Freezing Drizzle                             100.202857  101.02   98.44
# Freezing Drizzle,Fog                         100.441667  101.27   98.74
# Freezing Drizzle,Haze                        100.316667  100.36  100.28
# Freezing Drizzle,Snow                        100.520909  101.18   99.19
# Freezing Fog                                 102.320000  102.85  101.97
# Freezing Rain                                 99.647143  101.00   98.22
# Freezing Rain,Fog                             99.945000  101.01   98.32
# Freezing Rain,Haze                           100.375000  100.41  100.34
# Freezing Rain,Ice Pellets,Fog                100.950000  100.95  100.95
# Freezing Rain,Snow Grains                     98.560000   98.56   98.56
# Haze                                         101.482500  102.97  100.35
# Mainly Clear                                 101.248832  103.59   98.67
# Moderate Rain,Fog                             99.980000   99.98   99.98
# Moderate Snow                                100.275000  100.67   99.88
# Moderate Snow,Blowing Snow                   100.570000  100.64  100.50
# Mostly Cloudy                                101.025288  103.65   98.36
# Rain                                         100.233333  102.26   97.52
# Rain Showers                                 100.404043  102.31   98.51
# Rain Showers,Fog                              99.830000   99.83   99.83
# Rain Showers,Snow Showers                    101.100000  101.11  101.09
# Rain,Fog                                     100.500862  101.77   98.61
# Rain,Haze                                    100.540000  100.61  100.50
# Rain,Ice Pellets                             100.120000  100.12  100.12
# Rain,Snow                                     99.951111  101.07   98.18
# Rain,Snow Grains                             100.600000  100.60  100.60
# Rain,Snow,Fog                                100.730000  100.73  100.73
# Rain,Snow,Ice Pellets                        100.105000  100.47   99.85
# Snow                                         100.536103  102.73   97.75
# Snow Pellets                                  99.700000   99.70   99.70
# Snow Showers                                 100.963500  102.50   99.49
# Snow Showers,Fog                             101.292500  102.52  100.63
# Snow,Blowing Snow                             99.704737  100.62   98.11
# Snow,Fog                                     100.688649  102.07   99.38
# Snow,Haze                                    100.782000  100.99  100.61
# Snow,Ice Pellets                             100.548333  100.96   99.40
# Thunderstorms                                100.230000  100.62   99.84
# Thunderstorms,Heavy Rain Showers             100.260000  100.26  100.26
# Thunderstorms,Moderate Rain Showers,Fog      100.010000  100.01  100.01
# Thunderstorms,Rain                           100.420000  100.83  100.19
# Thunderstorms,Rain Showers                   100.233750  101.06   99.65
# Thunderstorms,Rain Showers,Fog               100.063333  100.64   99.71
# Thunderstorms,Rain,Fog                       100.080000  100.08  100.08
#
#
#                                                sum count     len
# Weather
# Clear                                    134704.95  1326  1326.0
# Cloudy                                   174374.97  1728  1728.0
# Drizzle                                    4117.85    41    41.0
# Drizzle,Fog                                8062.93    80    80.0
# Drizzle,Ice Pellets,Fog                     100.79     1     1.0
# Drizzle,Snow                                201.78     2     2.0
# Drizzle,Snow,Fog                           1489.22    15    15.0
# Fog                                       15177.61   150   150.0
# Freezing Drizzle                            701.42     7     7.0
# Freezing Drizzle,Fog                        602.65     6     6.0
# Freezing Drizzle,Haze                       300.95     3     3.0
# Freezing Drizzle,Snow                      1105.73    11    11.0
# Freezing Fog                                409.28     4     4.0
# Freezing Rain                              1395.06    14    14.0
# Freezing Rain,Fog                           399.78     4     4.0
# Freezing Rain,Haze                          200.75     2     2.0
# Freezing Rain,Ice Pellets,Fog               100.95     1     1.0
# Freezing Rain,Snow Grains                    98.56     1     1.0
# Haze                                       1623.72    16    16.0
# Mainly Clear                             213230.04  2106  2106.0
# Moderate Rain,Fog                            99.98     1     1.0
# Moderate Snow                               401.10     4     4.0
# Moderate Snow,Blowing Snow                  201.14     2     2.0
# Mostly Cloudy                            209021.32  2069  2069.0
# Rain                                      30671.40   306   306.0
# Rain Showers                              18875.96   188   188.0
# Rain Showers,Fog                             99.83     1     1.0
# Rain Showers,Snow Showers                   202.20     2     2.0
# Rain,Fog                                  11658.10   116   116.0
# Rain,Haze                                   301.62     3     3.0
# Rain,Ice Pellets                            100.12     1     1.0
# Rain,Snow                                  1799.12    18    18.0
# Rain,Snow Grains                            100.60     1     1.0
# Rain,Snow,Fog                               100.73     1     1.0
# Rain,Snow,Ice Pellets                       400.42     4     4.0
# Snow                                      39209.08   390   390.0
# Snow Pellets                                 99.70     1     1.0
# Snow Showers                               6057.81    60    60.0
# Snow Showers,Fog                            405.17     4     4.0
# Snow,Blowing Snow                          1894.39    19    19.0
# Snow,Fog                                   3725.48    37    37.0
# Snow,Haze                                   503.91     5     5.0
# Snow,Ice Pellets                            603.29     6     6.0
# Thunderstorms                               200.46     2     2.0
# Thunderstorms,Heavy Rain Showers            100.26     1     1.0
# Thunderstorms,Moderate Rain Showers,Fog     100.01     1     1.0
# Thunderstorms,Rain                          301.26     3     3.0
# Thunderstorms,Rain Showers                 1603.74    16    16.0
# Thunderstorms,Rain Showers,Fog              300.19     3     3.0
# Thunderstorms,Rain,Fog                      100.08     1     1.0
#
# [50 rows x 36 columns]

# %% [markdown]
# You want to convert Celsius temperature into Fahrenheit temperatures. Call the function convert to do the same.

# %%
df.head(1)
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa) Weather
# 0                4              8.0           101.24     Fog

# %%
convert=df['Temp (C)'].apply(lambda x: x*1.8+32 ) #Using lambda function
convert
# Out:
# 0       28.76
# 1       28.76
# 2       28.76
# 3       29.30
# 4       29.30
#         ...
# 8779    32.18
# 8780    32.36
# 8781    31.10
# 8782    31.64
# 8783    32.00
# Name: Temp (C), Length: 8784, dtype: float64

# %% [markdown]
# Using simple function

# %%
#USing simple function
temperatures = df['Temp (C)']
def converter(cel):
    return cel*1.8+32
converter(temperatures)
# Out:
# 0       28.76
# 1       28.76
# 2       28.76
# 3       29.30
# 4       29.30
#         ...
# 8779    32.18
# 8780    32.36
# 8781    31.10
# 8782    31.64
# 8783    32.00
# Name: Temp (C), Length: 8784, dtype: float64

# %% [markdown]
# PIVOT TABLE Index AS Weather

# %%
df.pivot_table(index=['Weather'],values=['Dew Point Temp (C)','Visibility (km)'],aggfunc=[np.mean,np.max,np.min])
# Out:
#                                                       mean                  \
#                                         Dew Point Temp (C) Visibility (km)
# Weather
# Clear                                             0.089367       30.153243
# Cloudy                                            2.375810       26.625752
# Drizzle                                           5.504878       17.931707
# Drizzle,Fog                                       7.033750        5.257500
# Drizzle,Ice Pellets,Fog                          -0.700000        4.000000
# Drizzle,Snow                                      0.150000       10.500000
# Drizzle,Snow,Fog                                  0.120000        5.513333
# Fog                                               3.159333        6.248000
# Freezing Drizzle                                 -8.000000        9.200000
# Freezing Drizzle,Fog                             -4.183333        5.266667
# Freezing Drizzle,Haze                            -8.000000        2.666667
# Freezing Drizzle,Snow                            -7.072727        5.872727
# Freezing Fog                                     -9.250000        0.650000
# Freezing Rain                                    -6.078571        8.242857
# Freezing Rain,Fog                                -3.750000        7.550000
# Freezing Rain,Haze                               -7.450000        2.400000
# Freezing Rain,Ice Pellets,Fog                    -3.700000        8.000000
# Freezing Rain,Snow Grains                        -7.300000        4.800000
# Haze                                             -2.975000        7.831250
# Mainly Clear                                      4.581671       34.264862
# Moderate Rain,Fog                                 0.800000        6.400000
# Moderate Snow                                    -7.250000        0.750000
# Moderate Snow,Blowing Snow                       -6.500000        0.600000
# Mostly Cloudy                                     3.131174       31.253842
# Rain                                              7.042810       18.856536
# Rain Showers                                      9.187766       22.816489
# Rain Showers,Fog                                 12.100000        6.400000
# Rain Showers,Snow Showers                        -1.500000       21.700000
# Rain,Fog                                          7.219828        6.873276
# Rain,Haze                                         2.066667        6.700000
# Rain,Ice Pellets                                 -0.600000        9.700000
# Rain,Snow                                        -0.566667       11.672222
# Rain,Snow Grains                                 -2.100000       25.000000
# Rain,Snow,Fog                                     0.300000        6.400000
# Rain,Snow,Ice Pellets                            -0.175000        6.000000
# Snow                                             -7.623333       11.171795
# Snow Pellets                                     -6.400000        2.400000
# Snow Showers                                     -7.866667       20.158333
# Snow Showers,Fog                                -11.900000        7.025000
# Snow,Blowing Snow                                -7.621053        4.105263
# Snow,Fog                                         -6.364865        4.537838
# Snow,Haze                                        -6.860000        4.640000
# Snow,Ice Pellets                                 -3.666667        7.416667
# Thunderstorms                                    19.750000       24.550000
# Thunderstorms,Heavy Rain Showers                  9.000000        2.400000
# Thunderstorms,Moderate Rain Showers,Fog          18.500000        3.200000
# Thunderstorms,Rain                               18.533333       19.833333
# Thunderstorms,Rain Showers                       17.618750       15.893750
# Thunderstorms,Rain Showers,Fog                   18.700000        9.700000
# Thunderstorms,Rain,Fog                           18.600000        4.800000
#
#                                                       amax                  \
#                                         Dew Point Temp (C) Visibility (km)
# Weather
# Clear                                                 20.4            48.3
# Cloudy                                                22.6            48.3
# Drizzle                                               17.7            25.0
# Drizzle,Fog                                           19.1             9.7
# Drizzle,Ice Pellets,Fog                               -0.7             4.0
# Drizzle,Snow                                           0.2            11.3
# Drizzle,Snow,Fog                                       0.6             9.7
# Fog                                                   19.6             9.7
# Freezing Drizzle                                      -3.3            12.9
# Freezing Drizzle,Fog                                  -2.3             8.0
# Freezing Drizzle,Haze                                 -7.7             4.0
# Freezing Drizzle,Snow                                 -4.6            12.9
# Freezing Fog                                          -0.3             0.8
# Freezing Rain                                         -1.7            16.1
# Freezing Rain,Fog                                     -0.9             9.7
# Freezing Rain,Haze                                    -7.4             2.8
# Freezing Rain,Ice Pellets,Fog                         -3.7             8.0
# Freezing Rain,Snow Grains                             -7.3             4.8
# Haze                                                  11.1             9.7
# Mainly Clear                                          21.2            48.3
# Moderate Rain,Fog                                      0.8             6.4
# Moderate Snow                                         -6.7             0.8
# Moderate Snow,Blowing Snow                            -6.4             0.6
# Mostly Cloudy                                         24.4            48.3
# Rain                                                  20.4            48.3
# Rain Showers                                          23.0            48.3
# Rain Showers,Fog                                      12.1             6.4
# Rain Showers,Snow Showers                             -1.2            24.1
# Rain,Fog                                              19.5             9.7
# Rain,Haze                                              2.9             9.7
# Rain,Ice Pellets                                      -0.6             9.7
# Rain,Snow                                              0.5            25.0
# Rain,Snow Grains                                      -2.1            25.0
# Rain,Snow,Fog                                          0.3             6.4
# Rain,Snow,Ice Pellets                                  0.1             6.4
# Snow                                                   0.3            25.0
# Snow Pellets                                          -6.4             2.4
# Snow Showers                                          -0.7            48.3
# Snow Showers,Fog                                     -11.1             9.7
# Snow,Blowing Snow                                     -2.9             9.7
# Snow,Fog                                               0.8             9.7
# Snow,Haze                                             -6.4             6.4
# Snow,Ice Pellets                                      -1.7            11.3
# Thunderstorms                                         20.1            25.0
# Thunderstorms,Heavy Rain Showers                       9.0             2.4
# Thunderstorms,Moderate Rain Showers,Fog               18.5             3.2
# Thunderstorms,Rain                                    19.1            24.1
# Thunderstorms,Rain Showers                            23.1            25.0
# Thunderstorms,Rain Showers,Fog                        21.3             9.7
# Thunderstorms,Rain,Fog                                18.6             4.8
#
#                                                       amin
#                                         Dew Point Temp (C) Visibility (km)
# Weather
# Clear                                                -28.5            11.3
# Cloudy                                               -26.8            11.3
# Drizzle                                               -0.2             6.4
# Drizzle,Fog                                           -1.6             1.0
# Drizzle,Ice Pellets,Fog                               -0.7             4.0
# Drizzle,Snow                                           0.1             9.7
# Drizzle,Snow,Fog                                      -0.1             2.4
# Fog                                                  -17.2             0.2
# Freezing Drizzle                                     -12.2             4.8
# Freezing Drizzle,Fog                                  -9.0             3.6
# Freezing Drizzle,Haze                                 -8.3             2.0
# Freezing Drizzle,Snow                                -10.4             2.4
# Freezing Fog                                         -22.9             0.2
# Freezing Rain                                         -9.0             2.8
# Freezing Rain,Fog                                     -8.7             2.8
# Freezing Rain,Haze                                    -7.5             2.0
# Freezing Rain,Ice Pellets,Fog                         -3.7             8.0
# Freezing Rain,Snow Grains                             -7.3             4.8
# Haze                                                 -16.0             4.8
# Mainly Clear                                         -28.0            12.9
# Moderate Rain,Fog                                      0.8             6.4
# Moderate Snow                                         -7.6             0.6
# Moderate Snow,Blowing Snow                            -6.6             0.6
# Mostly Cloudy                                        -28.5            11.3
# Rain                                                  -5.7             4.0
# Rain Showers                                          -7.2             6.4
# Rain Showers,Fog                                      12.1             6.4
# Rain Showers,Snow Showers                             -1.8            19.3
# Rain,Fog                                              -1.2             2.0
# Rain,Haze                                              1.0             4.0
# Rain,Ice Pellets                                      -0.6             9.7
# Rain,Snow                                             -1.7             2.4
# Rain,Snow Grains                                      -2.1            25.0
# Rain,Snow,Fog                                          0.3             6.4
# Rain,Snow,Ice Pellets                                 -0.7             4.8
# Snow                                                 -24.6             1.0
# Snow Pellets                                          -6.4             2.4
# Snow Showers                                         -19.3             2.4
# Snow Showers,Fog                                     -12.7             4.0
# Snow,Blowing Snow                                    -16.2             0.6
# Snow,Fog                                             -12.0             1.2
# Snow,Haze                                             -7.2             4.0
# Snow,Ice Pellets                                      -5.9             2.8
# Thunderstorms                                         19.4            24.1
# Thunderstorms,Heavy Rain Showers                       9.0             2.4
# Thunderstorms,Moderate Rain Showers,Fog               18.5             3.2
# Thunderstorms,Rain                                    18.2            16.1
# Thunderstorms,Rain Showers                             7.0             6.4
# Thunderstorms,Rain Showers,Fog                        16.1             9.7
# Thunderstorms,Rain,Fog                                18.6             4.8

# %%
# #Importing the modules
# import pandas as pd
# import numpy as np
# from scipy.stats import mode 

# #Code for categorical variable
# def categorical(df):
#     """ Extract names of categorical column
    
#     This function accepts a dataframe and returns categorical list,
#     containing the names of categorical columns(categorical_var).
    
#     Keyword arguments:
#     df - Pandas dataframe from which the columns name will be extracted
        
#     Returns:
#     categorical_var - List of categorical features
#     """
#     categorical_var= df.select_dtypes(include='object').columns.tolist()
#     return categorical_var


# #Code for numerical variable
# def numerical(df):
#     """ Extract names of numerical column
    
#     This function accepts a dataframe and returns numerical list,
#     containing the names of numerical columns(numerical_var).
        
#     Keyword arguments:
#     df - Pandas dataframe from which the columns name will be extracted
    
#     Returns:
#     numerical_var - List of numerical features
#     """
#     numerical_var = df.select_dtypes(include='number').columns.tolist()
#     return numerical_var


# #code to check distribution of variable
# def clear(df,col,val):
#     """ Check distribution of variable
    
#     This function accepts a dataframe,column(feature) and value which returns count of the value,
#     containing the value counts of a variable(value_counts)
    
#     Keyword arguments:
#     df - Pandas dataframe
#     col - Feature of the datagrame
#     val - value of the feature
    
#     Returns:
#     value_counts - Value count of the feature 
#     """
#     value_counts = df[col].value_counts()[val]
#     return value_counts


# #Code to check instances based on the condition
# def instances_based_condition(df,col1,val1,col2,val2):
#     """ Instances based on the condition
    
#     This function accepts a dataframe, 2 columns(feature) and 2 values which returns the dataframe
#     based on the condition.
    
#     Keyword arguments:
#     df - Pandas dataframe which has the data.
#     col1 - First feature of the dataframe on which you want to apply the filter
#     val1 - Value to be filtered on the first feature
#     col2 - Second feature of the dataframe on which you want to apply the filter
#     val2 - Value to be filtered on second feature
    
#     Returns:
#     instance - Generated dataframe
#     """
    
#     instance = df[(df[col1] > val1) & (df[col2]== val2)]
#     return instance


# # Code to calculate different aggreagted values according to month

# def agg_values_ina_month(df,date_col,agg_col, agg):
#     """  Aggregate values according to month
    
#     This function accepts a dataframe, 2 columns(feature) and aggregated funcion(agg) which returns the Pivot 
#     table with different aggregated value of the feature with an index of the month.
     
#     Keyword arguments:
#     df - Pandas dataframe which has the data.
#     date_col - Date feature of the dataframe on which you want to apply to_datetime conversion
#     agg_col - Feature of the dataframe on which values will be aggregated.
#     agg - Dictionary of aggregate functions with feature as the key and func as the value
    
#     Returns:
#     aggregated_value - Generated pivot table
#     """
#     df[date_col] = pd.to_datetime(df[date_col])
#     aggregate = {'mean':np.mean,'max':np.max,'min':np.min,'sum':np.sum,'len':len}
#     aggregated_value = df.pivot_table(values=[agg_col], index=df[date_col].dt.month,aggfunc={agg_col:aggregate[agg]})
#     return aggregated_value


# # Code to group values based on the feature
# def group_values(df,col1,agg1):
#     """ Agrregate values by grouping
    
#     This function accepts a dataframe, 1 column(feature) and aggregated function(agg1) which groupby the datframe based on the column.
    
    
#     Keyword arguments:
#     df - Pandas dataframe which has the data.
#     col1 - Feature of the dataframe on which values will be aggregated.
#     agg1 - Dictionary of aggregate functions with feature as the key and func as the value
    
#     Returns:
#     grouping - Dataframe with all columns on which it is grouped on.
#     """
    
#     aggregate = {'mean':np.mean,'max':np.max,'min':np.min,'sum':np.sum,'len':len}
#     grouping = df.groupby(col1).agg(aggregate[agg1])
#     return grouping


# # function for conversion 
# def convert(df,celsius):
#     """ Convert temperatures from celsius to fahrenhheit
    
#     This function accepts a dataframe, 1 column(feature) which returns the dataframe with converted values from 
#     celsius to fahrenhheit.
         
#     Keyword arguments:
#     df - Pandas dataframe which has the data.
#     celsius - Temperature feature of the dataframe which you want to convert to fahrenhheit
    
#     Returns:
#     converted_temp - Generated dataframe with Fahrenhheit temp.
    
#     """
#     centigrade_temps = df[celsius]
#     converted_temp =  1.8*centigrade_temps + 32
#     return converted_temp



# # Load the weather_2012 data csv file and store it in weather variable. The path of the dataset has been stored in the variable `path` for you.
# weather = pd.read_csv('weather.csv')
# weather.head()


# # As now you have loaded the weather data you might want to check the categorical and numerical variables. You can check it by calling categorical and numerical function. 
# print(categorical(weather))
# print(numerical(weather))


# #You might be interested in checking the distribution of a specific value like the number of times the weather was exactly Cloudy in the given column. Feel free to check on other values.
# #You can check it by calling the function clear with respective parameters.
# #By using index of the value or name of the value you can check the number of count


# print(clear(weather,"Weather",'Clear'))
# print(clear(weather,"Wind Spd (km/h)", 4))


# # Now suppose you want to check some instances based on a specific condition like when the wind speed was above 35 and visibility was 25. You can dicretly check it by calling the function instances_based_condition with respective parameters.


# wind_speed_35_vis_25 = instances_based_condition(weather,'Wind Spd (km/h)',35,'Visibility (km)',25)


# #You have temperature data and want to calculate the mean temperature recorded by month.You can generate a pivot table which contains the aggregated values(like mean, max ,min, sum, len) recoreded by month. 
# #You can call the function agg_values_ina_month with respective parameters. 



# # To groupby based on a column like you want to groupby on Weather column and then aggregate the mean  values of each column for different types of weather using mean. You can call the function group_values.
# # Feel free to try on diffrent aggregated functions like max, min, sum, len

# mean_weather = group_values(weather,"Weather",'mean')


# # You have a temperature data and wanted to convert celsius temperature into fahrehheit temperatures you can call the function convert.

# weather_fahrehheit = convert(weather,"Temp (C)")
